# %%
import pandas as pd

# %%
file=pd.read_csv('C:\\Users\\sowmy\\Downloads\\credit_card (1).csv')
file
# Out:
#      OBS#  CHK_ACCT  DURATION  HISTORY  NEW_CAR  USED_CAR  FURNITURE  \
# 0       1         0         6        4        0         0          0
# 1       2         1        48        2        0         0          0
# 2       3         3        12        4        0         0          0
# 3       4         0        42        2        0         0          1
# 4       5         0        24        3        1         0          0
# ..    ...       ...       ...      ...      ...       ...        ...
# 995   996         3        12        2        0         0          1
# 996   997         0        30        2        0         1          0
# 997   998         3        12        2        0         0          0
# 998   999         0        45        2        0         0          0
# 999  1000         1        45        4        0         1          0
#
#      RADIO/TV  EDUCATION  RETRAINING  ...  AGE  OTHER_INSTALL  RENT  OWN_RES  \
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBS#              1000 non-null   int64
#  1   CHK_ACCT          1000 non-null   int64
#  2   DURATION          1000 non-null   int64
#  3   HISTORY           1000 non-null   int64
#  4   NEW_CAR           1000 non-null   int64
#  5   USED_CAR          1000 non-null   int64
#  6   FURNITURE         1000 non-null   int64
#  7   RADIO/TV          1000 non-null   int64
#  8   EDUCATION         1000 non-null   int64
#  9   RETRAINING        1000 non-null   int64
#  10  AMOUNT            1000 non-null   int64
#  11  SAV_ACCT          1000 non-null   int64
#  12  EMPLOYMENT        1000 non-null   int64
#  13  INSTALL_RATE      1000 non-null   int64
#  14  MALE_DIV          1000 non-null   int64
#  15  MALE_SINGLE       1000 non-null   int64
# ...

# %%
file.describe()
# Out:
#               OBS#     CHK_ACCT     DURATION     HISTORY      NEW_CAR  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean    500.500000     1.577000    20.903000     2.54500     0.234000
# std     288.819436     1.257638    12.058814     1.08312     0.423584
# min       1.000000     0.000000     4.000000     0.00000     0.000000
# 25%     250.750000     0.000000    12.000000     2.00000     0.000000
# 50%     500.500000     1.000000    18.000000     2.00000     0.000000
# 75%     750.250000     3.000000    24.000000     4.00000     0.000000
# max    1000.000000     3.000000    72.000000     4.00000     1.000000
#
#           USED_CAR    FURNITURE     RADIO/TV    EDUCATION   RETRAINING  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean      0.103000     0.181000     0.280000     0.050000     0.097000  ...
# std       0.304111     0.385211     0.449224     0.218054     0.296106  ...
# ...

# %%
corr=file.corr()
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))

sns.heatmap(corr,annot=True,cmap='crest')
# Out:
# <AxesSubplot:>

# %%
file.hist(bins=60, figsize=(20,10),color='grey')
plt.show()

# %%
file.columns
# Out:
# Index(['OBS#', 'CHK_ACCT', 'DURATION', 'HISTORY', 'NEW_CAR', 'USED_CAR',
#        'FURNITURE', 'RADIO/TV', 'EDUCATION', 'RETRAINING', 'AMOUNT',
#        'SAV_ACCT', 'EMPLOYMENT', 'INSTALL_RATE', 'MALE_DIV', 'MALE_SINGLE',
#        'MALE_MAR_or_WID', 'CO-APPLICANT', 'GUARANTOR', 'PRESENT_RESIDENT',
#        'REAL_ESTATE', 'PROP_UNKN_NONE', 'AGE', 'OTHER_INSTALL', 'RENT',
#        'OWN_RES', 'NUM_CREDITS', 'JOB', 'NUM_DEPENDENTS', 'TELEPHONE',
#        'FOREIGN', 'RESPONSE'],
#       dtype='object')

# %%
import seaborn as sns

# %%
file.dtypes
# Out:
# OBS#                int64
# CHK_ACCT            int64
# DURATION            int64
# HISTORY             int64
# NEW_CAR             int64
# USED_CAR            int64
# FURNITURE           int64
# RADIO/TV            int64
# EDUCATION           int64
# RETRAINING          int64
# AMOUNT              int64
# SAV_ACCT            int64
# EMPLOYMENT          int64
# INSTALL_RATE        int64
# MALE_DIV            int64
# MALE_SINGLE         int64
# MALE_MAR_or_WID     int64
# CO-APPLICANT        int64
# GUARANTOR           int64
# PRESENT_RESIDENT    int64
# REAL_ESTATE         int64
# PROP_UNKN_NONE      int64
# AGE                 int64
# OTHER_INSTALL       int64
# RENT                int64
# OWN_RES             int64
# NUM_CREDITS         int64
# JOB                 int64
# NUM_DEPENDENTS      int64
# TELEPHONE           int64
# FOREIGN             int64
# RESPONSE            int64
# dtype: object

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,silhouette_samples

# %%
kmean= KMeans(n_clusters=7)

# %%
kmean.fit_predict(file)
# Out:
# array([1, 4, 5, 0, 2, 0, 5, 4, 5, 4, 1, 2, 1, 1, 1, 1, 5, 0, 3, 2, 5, 5,
#        5, 5, 5, 1, 1, 1, 5, 4, 5, 2, 4, 1, 1, 2, 4, 5, 1, 1, 5, 1, 4, 4,
#        4, 1, 5, 1, 0, 5, 5, 4, 1, 2, 5, 1, 4, 0, 5, 4, 1, 1, 5, 6, 2, 4,
#        5, 1, 5, 5, 0, 1, 1, 4, 5, 1, 2, 2, 0, 2, 4, 1, 1, 1, 5, 1, 1, 3,
#        5, 1, 1, 1, 1, 2, 1, 6, 5, 5, 5, 4, 1, 5, 1, 5, 5, 3, 4, 4, 0, 1,
#        1, 1, 4, 0, 1, 2, 0, 5, 2, 5, 5, 2, 1, 1, 5, 5, 1, 1, 5, 2, 0, 4,
#        5, 5, 3, 1, 0, 1, 5, 5, 1, 2, 2, 5, 5, 2, 1, 1, 4, 1, 1, 5, 4, 0,
#        4, 1, 1, 1, 2, 5, 5, 1, 1, 0, 1, 5, 1, 1, 2, 5, 1, 1, 5, 1, 2, 0,
#        5, 1, 5, 1, 0, 2, 1, 2, 1, 1, 4, 1, 1, 2, 2, 2, 2, 5, 5, 1, 1, 1,
#        5, 2, 1, 1, 4, 1, 1, 3, 5, 1, 4, 1, 5, 2, 4, 5, 2, 1, 5, 2, 5, 1,
#        1, 1, 1, 5, 2, 5, 3, 0, 1, 2, 2, 5, 5, 1, 1, 5, 6, 5, 1, 5, 1, 1,
#        2, 1, 2, 1, 1, 1, 5, 1, 1, 5, 5, 2, 5, 0, 5, 5, 2, 1, 1, 1, 4, 5,
#        1, 1, 4, 1, 0, 1, 5, 1, 3, 5, 3, 5, 5, 1, 2, 5, 2, 1, 1, 1, 2, 3,
# ...

# %%
score=silhouette_score(file,kmean.labels_,metric='euclidean')

# %%
print('Silhouetter_score:%.3f' %score)
# Out:
# Silhouetter_score:0.481

# %%
pip install yellowbrick
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yellowbrick
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer

# %%
fig,ax=plt.subplots(2,2,figsize=(15,5))
for i in[2,3,4,5]:
    km=KMeans(n_clusters=i,init='k-means++',n_init=10,max_iter=120,random_state=4)
    q,mod=divmod(i,2)
    visualizer=SilhouetteVisualizer(km,colors='yellowbrick',ax=ax[q-1][mod])
    visualizer.fit(file)
