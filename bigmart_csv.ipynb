# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file=pd.read_csv('/content/drive/MyDrive/0.MKCE/Datasets/bigmart_train.csv')
file
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
files=pd.DataFrame(file)
files
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
file.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
file.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
file.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
file.shape
# Out:
# (8523, 12)

# %%
file.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
file.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
num_fea = file.dtypes[file.dtypes != "object"].index
print(num_fea)
print(len(num_fea))
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')
# 5

# %%
cat_fea =file.dtypes[file.dtypes == "object"].index
print(cat_fea)
print(len(cat_fea))
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')
# 7

# %%
type(num_fea)
# Out:
# pandas.core.indexes.base.Index

# %%
sns.set(font_scale=1.2)

f = pd.melt(file, id_vars=['Item_Outlet_Sales'], value_vars=cat_fea)
facetobject = sns.FacetGrid(f, col="variable", col_wrap=2, sharex=False, sharey=False, size=6)
facetobject.map(sns.boxplot, "value", "Item_Outlet_Sales", palette="Set3")
facetobject.fig.subplots_adjust(wspace=.25, hspace=0.25)


for ax in facetobject.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df_num_fea= file.select_dtypes(include=[np.number])
corr= df_num_fea.corr()
corr["Item_Outlet_Sales"].sort_values(ascending=False)*100
f, ax= plt.subplots(figsize=(14,14))
plt.title("Correlation of Numeric Features", y=1, size=20)
sns.heatmap(corr, square= True, vmin=-0.2, vmax=0.8, cmap="YlGnBu")

# %%
missing_values=file.columns[file.isnull().any()]
file[missing_values].isnull().sum()
# Out:
# Item_Weight    1463
# Outlet_Size    2410
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
labels = []
valuecount = []
percentcount = []
for col in missing_values:
    labels.append(col)
    valuecount.append(file[col].isnull().sum())
    percentcount.append(file[col].isnull().sum()/file.shape[0]) 
ind = np.arange(len(labels))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))
rects = ax1.barh(ind, np.array(valuecount), color='yellow')
ax1.set_yticks(ind)
ax1.set_yticklabels(labels, rotation='horizontal')
ax1.set_xlabel("Count of missing values")
ax1.set_title("Variables with missing values");
rects = ax2.barh(ind, np.array(percentcount), color='green')
ax2.set_yticks(ind)
ax2.set_yticklabels(labels, rotation='horizontal')
ax2.set_xlabel("Percentage of missing values")
ax2.set_title("Variables with missing values");

# %%
file.hist(bins=100, figsize=(40,25),color='indigo')
plt.show()

# %%
corr=file.corr()
import seaborn as sns

# %%
plt.figure(figsize=(25,10))

sns.heatmap(corr,annot=True,cmap='Set3')

# %%
sns.pairplot(file,kind='box')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=file, x='Item_Fat_Content')

# %%
file.duplicated().sum()
# Out:
# 0

# %%
file.corr().style.background_gradient(cmap="gnuplot2_r")
# Out:
# <style type="text/css">
# #T_a0671_row0_col0, #T_a0671_row1_col1, #T_a0671_row2_col2, #T_a0671_row3_col3, #T_a0671_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a0671_row0_col1 {
#   background-color: #fff609;
#   color: #000000;
# }
# #T_a0671_row0_col2, #T_a0671_row4_col0 {
#   background-color: #ffffa7;
#   color: #000000;
# }
# #T_a0671_row0_col3 {
#   background-color: #ffff43;
#   color: #000000;
# }
# #T_a0671_row0_col4 {
#   background-color: #ffe817;
#   color: #000000;
# }
# #T_a0671_row1_col0, #T_a0671_row1_col2, #T_a0671_row1_col3, #T_a0671_row1_col4, #T_a0671_row3_col0, #T_a0671_row4_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_a0671_row2_col0 {
#   background-color: #ffff82;
#   color: #000000;
# }
# #T_a0671_row2_col1 {
#   background-color: #fff00f;
#   color: #000000;
# }
# #T_a0671_row2_col3 {
#   background-color: #ffff11;
#   color: #000000;
# }
# #T_a0671_row2_col4 {
#   background-color: #6b00ff;
# ...

# %%
p0=file.Item_Outlet_Sales.min()
p100=file.Item_Outlet_Sales.max()

# %%
q1=file.Item_Outlet_Sales.quantile(0.25)
q2=file.Item_Outlet_Sales.quantile(0.5)
q3=file.Item_Outlet_Sales.quantile(0.75)

# %%
iqr=q3-q1
iqr
# Out:
# 2267.049

# %%
lower_cutoff=q1-1.5*iqr
lower_cutoff
# Out:
# -2566.3261

# %%
upper_cutoff=q3+1.5*iqr
upper_cutoff
# Out:
# 6501.8699

# %%
sns.boxplot(file.Item_Outlet_Sales,color='lavender')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
file.Item_Outlet_Sales.clip(upper=upper_cutoff)
file.Item_Outlet_Sales.plot(kind='box')

# %%
file.Item_Outlet_Sales.clip(upper=upper_cutoff,inplace=True)
file.Item_Outlet_Sales.plot(kind='box')

# %%
file.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
file.isna().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  2410
# Item_Weight                  1463
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
file.isna().sum()/file.shape[0]
# Out:
# Item_Identifier              0.000000
# Item_Weight                  0.171653
# Item_Fat_Content             0.000000
# Item_Visibility              0.000000
# Item_Type                    0.000000
# Item_MRP                     0.000000
# Outlet_Identifier            0.000000
# Outlet_Establishment_Year    0.000000
# Outlet_Size                  0.282764
# Outlet_Location_Type         0.000000
# Outlet_Type                  0.000000
# Item_Outlet_Sales            0.000000
# dtype: float64

# %%
file.Outlet_Size.mode()
# Out:
# 0    Medium
# dtype: object

# %%
file.dropna(axis=1,inplace=True)
file
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
file.Item_Outlet_Sales.hist()

# %%
file.select_dtypes(['float64','int64']).corr()
# Out:
#                            Item_Visibility  Item_MRP  \
# Item_Visibility                   1.000000 -0.001315
# Item_MRP                         -0.001315  1.000000
# Outlet_Establishment_Year        -0.074834  0.005020
# Item_Outlet_Sales                -0.131600  0.574554
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Visibility                            -0.074834          -0.131600
# Item_MRP                                    0.005020           0.574554
# Outlet_Establishment_Year                   1.000000          -0.037133
# Item_Outlet_Sales                          -0.037133           1.000000

# %%
file.groupby('Item_Outlet_Sales').Outlet_Type.sum()
# Out:
# Item_Outlet_Sales
# 33.2900                             Grocery StoreGrocery Store
# 33.9558                                          Grocery Store
# 34.6216                                          Grocery Store
# 35.2874                                          Grocery Store
# 36.6190                             Grocery StoreGrocery Store
#                                    ...
# 6465.5838                                    Supermarket Type3
# 6471.5760                   Supermarket Type1Supermarket Type1
# 6474.2392    Supermarket Type1Supermarket Type1Supermarket ...
# 6478.2340                                    Supermarket Type3
# 6501.8699    Supermarket Type2Supermarket Type3Supermarket ...
# Name: Outlet_Type, Length: 3323, dtype: object
